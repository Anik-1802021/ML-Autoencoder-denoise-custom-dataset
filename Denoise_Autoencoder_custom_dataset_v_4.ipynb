# %% [markdown]
# <a href="https://colab.research.google.com/github/Anik-1802021/ML-Autoencoder-denoise-custom-dataset/blob/main/Denoise_Autoencoder_custom_dataset_v_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D
from keras.models import Model
import cv2

# Function to calculate PSNR
def psnr(img1, img2):
    mse = np.mean((img1 - img2) ** 2)
    if mse == 0:
        return float('inf')
    max_pixel = 1.0  # As the pixel values are normalized to [0, 1]
    psnr_value = 20 * np.log10(max_pixel / np.sqrt(mse))
    return psnr_value

# Function to load and preprocess images
def load_images_from_folder(folder, image_size=(512, 512)):
    images = []
    for filename in os.listdir(folder):
        img_path = os.path.join(folder, filename)
        if os.path.isfile(img_path):
            img = plt.imread(img_path, format='grayscale')  # Load image in grayscale
            img = img / 255.0  # Normalize pixel values to [0, 1]
            img = img.astype('float32')
            img = np.expand_dims(img, axis=-1)  # Add channel dimension
            img = np.resize(img, image_size)  # Resize image to specified dimensions
            images.append(img)
    images = np.array(images)
    return images

# Load images from the specified dataset folder
dataset_folder = '/content/drive/MyDrive/Thesis/Swin Transformer /custom_dataset/test/NORMAL'
image_size = (512, 512)
images = load_images_from_folder(dataset_folder, image_size)

# Split data into training and test sets
x_train = images[:int(0.8 * len(images))]
x_test = images[int(0.8 * len(images)):]

# Add noise to the data
noise_factor = 0.2
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# Define the denoising autoencoder model
def denoising_autoencoder(input_shape):
    inputs = Input(shape=input_shape)
    # Encoder
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    pool1 = MaxPooling2D((2, 2), padding='same')(conv1)
    # Decoder
    conv2 = Conv2D(32, (3, 3), activation='relu', padding='same')(pool1)
    up1 = UpSampling2D((2, 2))(conv2)
    # Output
    outputs = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(up1)
    model = Model(inputs, outputs)
    return model

# Create and compile the denoising autoencoder model
input_shape = (image_size[0], image_size[1], 1)
denoise_model = denoising_autoencoder(input_shape)
denoise_model.compile(optimizer='adam', loss='binary_crossentropy')

# Train the model
history = denoise_model.fit(x_train_noisy, x_train, epochs=200, batch_size=16, validation_data=(x_test_noisy, x_test))

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Predict on test data
denoised_images = denoise_model.predict(x_test_noisy)

# Display one original, noisy, and denoised image each
plt.figure(figsize=(15, 5))

# Original Image
plt.subplot(1, 3, 1)
plt.imshow(x_test[0], cmap='gray')
plt.title('Original Image')

# Noisy Image
plt.subplot(1, 3, 2)
plt.imshow(x_test_noisy[0], cmap='gray')
plt.title('Noisy Image')

# Denoised Image
plt.subplot(1, 3, 3)
plt.imshow(denoised_images[0], cmap='gray')
plt.title('Denoised Image')

plt.tight_layout()
plt.show()

# Calculate PSNR between original and noisy image
psnr_noisy = psnr(x_test[0], x_test_noisy[0])
print("PSNR between original and noisy image:", psnr_noisy)

# Calculate PSNR between original and denoised image
psnr_denoised = psnr(x_test[0], denoised_images[0])
print("PSNR between original and denoise image:", psnr_denoised)
# Out:
# Epoch 1/200
# 13/13 [==============================] - 121s 9s/step - loss: 0.5993 - val_loss: 0.5257
# Epoch 2/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.4901 - val_loss: 0.4287
# Epoch 3/200
# 13/13 [==============================] - 121s 9s/step - loss: 0.4048 - val_loss: 0.3810
# Epoch 4/200
# 13/13 [==============================] - 121s 9s/step - loss: 0.3761 - val_loss: 0.3741
# Epoch 5/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3721 - val_loss: 0.3698
# Epoch 6/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3673 - val_loss: 0.3673
# Epoch 7/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3648 - val_loss: 0.3651
# Epoch 8/200
# 13/13 [==============================] - 122s 9s/step - loss: 0.3628 - val_loss: 0.3637
# Epoch 9/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3615 - val_loss: 0.3627
# Epoch 10/200
# 13/13 [==============================] - 122s 9s/step - loss: 0.3605 - val_loss: 0.3620
# Epoch 11/200
# 13/13 [==============================] - 122s 9s/step - loss: 0.3599 - val_loss: 0.3614
# Epoch 12/200
# 13/13 [==============================] - 123s 10s/step - loss: 0.3593 - val_loss: 0.3610
# Epoch 13/200
# 13/13 [==============================] - 122s 9s/step - loss: 0.3589 - val_loss: 0.3606
# Epoch 14/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3586 - val_loss: 0.3604
# Epoch 15/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3584 - val_loss: 0.3600
# Epoch 16/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3581 - val_loss: 0.3598
# Epoch 17/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3578 - val_loss: 0.3595
# Epoch 18/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3576 - val_loss: 0.3594
# Epoch 19/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3574 - val_loss: 0.3595
# Epoch 20/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3573 - val_loss: 0.3590
# Epoch 21/200
# 13/13 [==============================] - 121s 9s/step - loss: 0.3571 - val_loss: 0.3591
# Epoch 22/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3571 - val_loss: 0.3588
# Epoch 23/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3569 - val_loss: 0.3590
# Epoch 24/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3569 - val_loss: 0.3589
# Epoch 25/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3567 - val_loss: 0.3584
# Epoch 26/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3565 - val_loss: 0.3582
# Epoch 27/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3564 - val_loss: 0.3581
# Epoch 28/200
# 13/13 [==============================] - 116s 9s/step - loss: 0.3563 - val_loss: 0.3582
# Epoch 29/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3562 - val_loss: 0.3583
# Epoch 30/200
# 13/13 [==============================] - 120s 9s/step - loss: 0.3562 - val_loss: 0.3580
# Epoch 31/200
# 13/13 [==============================] - 123s 10s/step - loss: 0.3560 - val_loss: 0.3578
# Epoch 32/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3559 - val_loss: 0.3576
# Epoch 33/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3558 - val_loss: 0.3576
# Epoch 34/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3557 - val_loss: 0.3576
# Epoch 35/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3556 - val_loss: 0.3572
# Epoch 36/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3554 - val_loss: 0.3571
# Epoch 37/200
# 13/13 [==============================] - 122s 9s/step - loss: 0.3553 - val_loss: 0.3570
# Epoch 38/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3552 - val_loss: 0.3569
# Epoch 39/200
# 13/13 [==============================] - 122s 9s/step - loss: 0.3551 - val_loss: 0.3566
# Epoch 40/200
# 13/13 [==============================] - 122s 9s/step - loss: 0.3549 - val_loss: 0.3565
# Epoch 41/200
# 13/13 [==============================] - 122s 9s/step - loss: 0.3547 - val_loss: 0.3563
# Epoch 42/200
# 13/13 [==============================] - 121s 9s/step - loss: 0.3546 - val_loss: 0.3561
# Epoch 43/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3545 - val_loss: 0.3560
# Epoch 44/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3544 - val_loss: 0.3558
# Epoch 45/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3542 - val_loss: 0.3557
# Epoch 46/200
# 13/13 [==============================] - 121s 9s/step - loss: 0.3541 - val_loss: 0.3555
# Epoch 47/200
# 13/13 [==============================] - 122s 9s/step - loss: 0.3540 - val_loss: 0.3556
# Epoch 48/200
# 13/13 [==============================] - 121s 9s/step - loss: 0.3540 - val_loss: 0.3555
# Epoch 49/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3539 - val_loss: 0.3551
# Epoch 50/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3537 - val_loss: 0.3551
# Epoch 51/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3536 - val_loss: 0.3550
# Epoch 52/200
# 13/13 [==============================] - 116s 9s/step - loss: 0.3535 - val_loss: 0.3549
# Epoch 53/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3535 - val_loss: 0.3548
# Epoch 54/200
# 13/13 [==============================] - 120s 9s/step - loss: 0.3534 - val_loss: 0.3547
# Epoch 55/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3533 - val_loss: 0.3546
# Epoch 56/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3533 - val_loss: 0.3545
# Epoch 57/200
# 13/13 [==============================] - 120s 9s/step - loss: 0.3532 - val_loss: 0.3545
# Epoch 58/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3531 - val_loss: 0.3549
# Epoch 59/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3531 - val_loss: 0.3544
# Epoch 60/200
# 13/13 [==============================] - 120s 9s/step - loss: 0.3531 - val_loss: 0.3543
# Epoch 61/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3530 - val_loss: 0.3547
# Epoch 62/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3531 - val_loss: 0.3545
# Epoch 63/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3530 - val_loss: 0.3543
# Epoch 64/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3529 - val_loss: 0.3542
# Epoch 65/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3528 - val_loss: 0.3540
# Epoch 66/200
# 13/13 [==============================] - 120s 9s/step - loss: 0.3527 - val_loss: 0.3552
# Epoch 67/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3529 - val_loss: 0.3541
# Epoch 68/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3527 - val_loss: 0.3540
# Epoch 69/200
# 13/13 [==============================] - 120s 9s/step - loss: 0.3526 - val_loss: 0.3539
# Epoch 70/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3526 - val_loss: 0.3540
# Epoch 71/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3525 - val_loss: 0.3538
# Epoch 72/200
# 13/13 [==============================] - 122s 9s/step - loss: 0.3525 - val_loss: 0.3540
# Epoch 73/200
# 13/13 [==============================] - 122s 9s/step - loss: 0.3525 - val_loss: 0.3538
# Epoch 74/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3524 - val_loss: 0.3544
# Epoch 75/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3526 - val_loss: 0.3545
# Epoch 76/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3526 - val_loss: 0.3541
# Epoch 77/200
# 13/13 [==============================] - 122s 9s/step - loss: 0.3526 - val_loss: 0.3538
# Epoch 78/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3524 - val_loss: 0.3537
# Epoch 79/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3523 - val_loss: 0.3538
# Epoch 80/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3522 - val_loss: 0.3536
# Epoch 81/200
# 13/13 [==============================] - 122s 9s/step - loss: 0.3522 - val_loss: 0.3538
# Epoch 82/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3522 - val_loss: 0.3535
# Epoch 83/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3521 - val_loss: 0.3535
# Epoch 84/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3521 - val_loss: 0.3536
# Epoch 85/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3521 - val_loss: 0.3538
# Epoch 86/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3522 - val_loss: 0.3536
# Epoch 87/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3520 - val_loss: 0.3537
# Epoch 88/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3522 - val_loss: 0.3533
# Epoch 89/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3520 - val_loss: 0.3536
# Epoch 90/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3520 - val_loss: 0.3533
# Epoch 91/200
# 13/13 [==============================] - 122s 9s/step - loss: 0.3520 - val_loss: 0.3535
# Epoch 92/200
# 13/13 [==============================] - 122s 9s/step - loss: 0.3520 - val_loss: 0.3532
# Epoch 93/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3519 - val_loss: 0.3534
# Epoch 94/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3519 - val_loss: 0.3532
# Epoch 95/200
# 13/13 [==============================] - 150s 12s/step - loss: 0.3519 - val_loss: 0.3533
# Epoch 96/200
# 13/13 [==============================] - 180s 14s/step - loss: 0.3519 - val_loss: 0.3531
# Epoch 97/200
# 13/13 [==============================] - 177s 14s/step - loss: 0.3518 - val_loss: 0.3532
# Epoch 98/200
# 13/13 [==============================] - 122s 9s/step - loss: 0.3517 - val_loss: 0.3533
# Epoch 99/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3518 - val_loss: 0.3531
# Epoch 100/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3518 - val_loss: 0.3532
# Epoch 101/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3517 - val_loss: 0.3532
# Epoch 102/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3517 - val_loss: 0.3531
# Epoch 103/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3517 - val_loss: 0.3530
# Epoch 104/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3517 - val_loss: 0.3530
# Epoch 105/200
# 13/13 [==============================] - 121s 9s/step - loss: 0.3516 - val_loss: 0.3529
# Epoch 106/200
# 13/13 [==============================] - 121s 9s/step - loss: 0.3516 - val_loss: 0.3529
# Epoch 107/200
# 13/13 [==============================] - 121s 9s/step - loss: 0.3515 - val_loss: 0.3529
# Epoch 108/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3515 - val_loss: 0.3529
# Epoch 109/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3515 - val_loss: 0.3529
# Epoch 110/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3515 - val_loss: 0.3528
# Epoch 111/200
# 13/13 [==============================] - 116s 9s/step - loss: 0.3514 - val_loss: 0.3528
# Epoch 112/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3515 - val_loss: 0.3528
# Epoch 113/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3514 - val_loss: 0.3528
# Epoch 114/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3514 - val_loss: 0.3532
# Epoch 115/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3516 - val_loss: 0.3531
# Epoch 116/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3515 - val_loss: 0.3528
# Epoch 117/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3515 - val_loss: 0.3528
# Epoch 118/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3514 - val_loss: 0.3528
# Epoch 119/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3514 - val_loss: 0.3527
# Epoch 120/200
# 13/13 [==============================] - 116s 9s/step - loss: 0.3513 - val_loss: 0.3527
# Epoch 121/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3513 - val_loss: 0.3527
# Epoch 122/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3514 - val_loss: 0.3527
# Epoch 123/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3513 - val_loss: 0.3526
# Epoch 124/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3512 - val_loss: 0.3526
# Epoch 125/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3512 - val_loss: 0.3526
# Epoch 126/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3512 - val_loss: 0.3527
# Epoch 127/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3512 - val_loss: 0.3525
# Epoch 128/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3511 - val_loss: 0.3525
# Epoch 129/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3512 - val_loss: 0.3525
# Epoch 130/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3511 - val_loss: 0.3526
# Epoch 131/200
# 13/13 [==============================] - 116s 9s/step - loss: 0.3512 - val_loss: 0.3526
# Epoch 132/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3512 - val_loss: 0.3526
# Epoch 133/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3512 - val_loss: 0.3530
# Epoch 134/200
# 13/13 [==============================] - 122s 9s/step - loss: 0.3513 - val_loss: 0.3527
# Epoch 135/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3512 - val_loss: 0.3528
# Epoch 136/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3512 - val_loss: 0.3524
# Epoch 137/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3510 - val_loss: 0.3528
# Epoch 138/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3511 - val_loss: 0.3523
# Epoch 139/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3510 - val_loss: 0.3523
# Epoch 140/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3510 - val_loss: 0.3527
# Epoch 141/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3511 - val_loss: 0.3525
# Epoch 142/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3511 - val_loss: 0.3526
# Epoch 143/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3510 - val_loss: 0.3524
# Epoch 144/200
# 13/13 [==============================] - 116s 9s/step - loss: 0.3510 - val_loss: 0.3523
# Epoch 145/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3510 - val_loss: 0.3525
# Epoch 146/200
# 13/13 [==============================] - 120s 9s/step - loss: 0.3510 - val_loss: 0.3524
# Epoch 147/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3510 - val_loss: 0.3523
# Epoch 148/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3510 - val_loss: 0.3522
# Epoch 149/200
# 13/13 [==============================] - 120s 9s/step - loss: 0.3509 - val_loss: 0.3524
# Epoch 150/200
# 13/13 [==============================] - 122s 9s/step - loss: 0.3509 - val_loss: 0.3522
# Epoch 151/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3508 - val_loss: 0.3522
# Epoch 152/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3508 - val_loss: 0.3522
# Epoch 153/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3508 - val_loss: 0.3524
# Epoch 154/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3508 - val_loss: 0.3523
# Epoch 155/200
# 13/13 [==============================] - 120s 9s/step - loss: 0.3508 - val_loss: 0.3521
# Epoch 156/200
# 13/13 [==============================] - 120s 9s/step - loss: 0.3509 - val_loss: 0.3522
# Epoch 157/200
# 13/13 [==============================] - 122s 9s/step - loss: 0.3508 - val_loss: 0.3522
# Epoch 158/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3508 - val_loss: 0.3527
# Epoch 159/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3511 - val_loss: 0.3532
# Epoch 160/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3511 - val_loss: 0.3525
# Epoch 161/200
# 13/13 [==============================] - 121s 9s/step - loss: 0.3509 - val_loss: 0.3523
# Epoch 162/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3507 - val_loss: 0.3521
# Epoch 163/200
# 13/13 [==============================] - 144s 11s/step - loss: 0.3507 - val_loss: 0.3521
# Epoch 164/200
# 13/13 [==============================] - 197s 15s/step - loss: 0.3507 - val_loss: 0.3522
# Epoch 165/200
# 13/13 [==============================] - 180s 14s/step - loss: 0.3507 - val_loss: 0.3520
# Epoch 166/200
# 13/13 [==============================] - 179s 14s/step - loss: 0.3507 - val_loss: 0.3521
# Epoch 167/200
# 13/13 [==============================] - 153s 12s/step - loss: 0.3507 - val_loss: 0.3521
# Epoch 168/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3507 - val_loss: 0.3520
# Epoch 169/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3507 - val_loss: 0.3520
# Epoch 170/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3507 - val_loss: 0.3529
# Epoch 171/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3509 - val_loss: 0.3520
# Epoch 172/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3507 - val_loss: 0.3522
# Epoch 173/200
# 13/13 [==============================] - 121s 9s/step - loss: 0.3507 - val_loss: 0.3534
# Epoch 174/200
# 13/13 [==============================] - 121s 9s/step - loss: 0.3510 - val_loss: 0.3519
# Epoch 175/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3506 - val_loss: 0.3522
# Epoch 176/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3507 - val_loss: 0.3530
# Epoch 177/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3509 - val_loss: 0.3521
# Epoch 178/200
# 13/13 [==============================] - 120s 9s/step - loss: 0.3506 - val_loss: 0.3519
# Epoch 179/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3505 - val_loss: 0.3520
# Epoch 180/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3505 - val_loss: 0.3524
# Epoch 181/200
# 13/13 [==============================] - 120s 9s/step - loss: 0.3506 - val_loss: 0.3521
# Epoch 182/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3506 - val_loss: 0.3520
# Epoch 183/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3506 - val_loss: 0.3526
# Epoch 184/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3507 - val_loss: 0.3518
# Epoch 185/200
# 13/13 [==============================] - 120s 9s/step - loss: 0.3505 - val_loss: 0.3520
# Epoch 186/200
# 13/13 [==============================] - 117s 9s/step - loss: 0.3505 - val_loss: 0.3518
# Epoch 187/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3505 - val_loss: 0.3519
# Epoch 188/200
# 13/13 [==============================] - 120s 9s/step - loss: 0.3505 - val_loss: 0.3520
# Epoch 189/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3506 - val_loss: 0.3517
# Epoch 190/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3504 - val_loss: 0.3517
# Epoch 191/200
# 13/13 [==============================] - 120s 9s/step - loss: 0.3504 - val_loss: 0.3518
# Epoch 192/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3504 - val_loss: 0.3519
# Epoch 193/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3505 - val_loss: 0.3517
# Epoch 194/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3504 - val_loss: 0.3520
# Epoch 195/200
# 13/13 [==============================] - 120s 9s/step - loss: 0.3504 - val_loss: 0.3523
# Epoch 196/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3506 - val_loss: 0.3517
# Epoch 197/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3503 - val_loss: 0.3517
# Epoch 198/200
# 13/13 [==============================] - 119s 9s/step - loss: 0.3503 - val_loss: 0.3519
# Epoch 199/200
# 13/13 [==============================] - 121s 9s/step - loss: 0.3503 - val_loss: 0.3517
# Epoch 200/200
# 13/13 [==============================] - 118s 9s/step - loss: 0.3503 - val_loss: 0.3517
# 2/2 [==============================] - 6s 2s/step
# PSNR between original and noisy image: 15.965293274340242
# PSNR between original and denoise image: 10.746518517244565
