# %% [markdown]
# <a href="https://colab.research.google.com/github/Anik-1802021/ML-Autoencoder-denoise-custom-dataset/blob/main/Denoise_Autoencoder_custom_dataset_v_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D
from keras.models import Model

# Function to load and preprocess images
def load_images_from_folder(folder, image_size=(512, 512)):
    images = []
    for filename in os.listdir(folder):
        img_path = os.path.join(folder, filename)
        if os.path.isfile(img_path):
            img = plt.imread(img_path, format='grayscale')  # Load image in grayscale
            img = img / 255.0  # Normalize pixel values to [0, 1]
            img = img.astype('float32')
            img = np.expand_dims(img, axis=-1)  # Add channel dimension
            img = np.resize(img, image_size)  # Resize image to specified dimensions
            images.append(img)
    images = np.array(images)
    return images

# Load images from the specified dataset folder
dataset_folder = '/content/drive/MyDrive/Thesis/Swin Transformer /custom_dataset/test/NORMAL'
image_size = (512, 512)
images = load_images_from_folder(dataset_folder, image_size)

# Split data into training and test sets
x_train = images[:int(0.8 * len(images))]
x_test = images[int(0.8 * len(images)):]

# Add noise to the data
noise_factor = 0.2
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# Define the denoising autoencoder model
def denoising_autoencoder(input_shape):
    inputs = Input(shape=input_shape)
    # Encoder
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    pool1 = MaxPooling2D((2, 2), padding='same')(conv1)
    # Decoder
    conv2 = Conv2D(32, (3, 3), activation='relu', padding='same')(pool1)
    up1 = UpSampling2D((2, 2))(conv2)
    # Output
    outputs = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(up1)
    model = Model(inputs, outputs)
    return model

# Create and compile the denoising autoencoder model
input_shape = (image_size[0], image_size[1], 1)
denoise_model = denoising_autoencoder(input_shape)
denoise_model.compile(optimizer='adam', loss='binary_crossentropy')

# Train the model
history = denoise_model.fit(x_train_noisy, x_train, epochs=50, batch_size=16, validation_data=(x_test_noisy, x_test))

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Predict on test data
denoised_images = denoise_model.predict(x_test_noisy)

# Display one original, noisy, and denoised image each
plt.figure(figsize=(15, 5))

# Original Image
plt.subplot(1, 3, 1)
plt.imshow(x_test[0], cmap='gray')
plt.title('Original Image')

# Noisy Image
plt.subplot(1, 3, 2)
plt.imshow(x_test_noisy[0], cmap='gray')
plt.title('Noisy Image')

# Denoised Image
plt.subplot(1, 3, 3)
plt.imshow(denoised_images[0], cmap='gray')
plt.title('Denoised Image')

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/50
# 13/13 [==============================] - 147s 11s/step - loss: 0.6319 - val_loss: 0.5467
# Epoch 2/50
# 13/13 [==============================] - 142s 11s/step - loss: 0.5207 - val_loss: 0.4580
# Epoch 3/50
# 13/13 [==============================] - 137s 11s/step - loss: 0.4274 - val_loss: 0.3922
# Epoch 4/50
# 13/13 [==============================] - 146s 11s/step - loss: 0.3819 - val_loss: 0.3748
# Epoch 5/50
# 13/13 [==============================] - 141s 11s/step - loss: 0.3744 - val_loss: 0.3732
# Epoch 6/50
# 13/13 [==============================] - 140s 11s/step - loss: 0.3705 - val_loss: 0.3692
# Epoch 7/50
# 13/13 [==============================] - 144s 11s/step - loss: 0.3670 - val_loss: 0.3667
# Epoch 8/50
# 13/13 [==============================] - 152s 12s/step - loss: 0.3645 - val_loss: 0.3651
# Epoch 9/50
# 13/13 [==============================] - 141s 11s/step - loss: 0.3628 - val_loss: 0.3637
# Epoch 10/50
# 13/13 [==============================] - 140s 11s/step - loss: 0.3613 - val_loss: 0.3624
# Epoch 11/50
# 13/13 [==============================] - 140s 11s/step - loss: 0.3601 - val_loss: 0.3615
# Epoch 12/50
# 13/13 [==============================] - 146s 11s/step - loss: 0.3591 - val_loss: 0.3605
# Epoch 13/50
# 13/13 [==============================] - 133s 10s/step - loss: 0.3582 - val_loss: 0.3596
# Epoch 14/50
# 13/13 [==============================] - 136s 10s/step - loss: 0.3573 - val_loss: 0.3590
# Epoch 15/50
# 13/13 [==============================] - 140s 11s/step - loss: 0.3566 - val_loss: 0.3584
# Epoch 16/50
# 13/13 [==============================] - 146s 11s/step - loss: 0.3561 - val_loss: 0.3579
# Epoch 17/50
# 13/13 [==============================] - 147s 11s/step - loss: 0.3557 - val_loss: 0.3575
# Epoch 18/50
# 13/13 [==============================] - 139s 11s/step - loss: 0.3552 - val_loss: 0.3571
# Epoch 19/50
# 13/13 [==============================] - 138s 11s/step - loss: 0.3548 - val_loss: 0.3567
# Epoch 20/50
# 13/13 [==============================] - 135s 10s/step - loss: 0.3545 - val_loss: 0.3565
# Epoch 21/50
# 13/13 [==============================] - 149s 12s/step - loss: 0.3542 - val_loss: 0.3561
# Epoch 22/50
# 13/13 [==============================] - 136s 10s/step - loss: 0.3540 - val_loss: 0.3557
# Epoch 23/50
# 13/13 [==============================] - 138s 11s/step - loss: 0.3537 - val_loss: 0.3555
# Epoch 24/50
# 13/13 [==============================] - 139s 10s/step - loss: 0.3535 - val_loss: 0.3553
# Epoch 25/50
# 13/13 [==============================] - 150s 12s/step - loss: 0.3533 - val_loss: 0.3551
# Epoch 26/50
# 13/13 [==============================] - 137s 11s/step - loss: 0.3531 - val_loss: 0.3549
# Epoch 27/50
# 13/13 [==============================] - 137s 10s/step - loss: 0.3529 - val_loss: 0.3547
# Epoch 28/50
# 13/13 [==============================] - 138s 11s/step - loss: 0.3528 - val_loss: 0.3545
# Epoch 29/50
# 13/13 [==============================] - 141s 11s/step - loss: 0.3526 - val_loss: 0.3544
# Epoch 30/50
# 13/13 [==============================] - 141s 11s/step - loss: 0.3525 - val_loss: 0.3543
# Epoch 31/50
# 13/13 [==============================] - 139s 11s/step - loss: 0.3524 - val_loss: 0.3541
# Epoch 32/50
# 13/13 [==============================] - 137s 11s/step - loss: 0.3522 - val_loss: 0.3541
# Epoch 33/50
# 13/13 [==============================] - 146s 11s/step - loss: 0.3522 - val_loss: 0.3539
# Epoch 34/50
# 13/13 [==============================] - 135s 10s/step - loss: 0.3520 - val_loss: 0.3539
# Epoch 35/50
# 13/13 [==============================] - 139s 11s/step - loss: 0.3520 - val_loss: 0.3537
# Epoch 36/50
# 13/13 [==============================] - 132s 10s/step - loss: 0.3519 - val_loss: 0.3535
# Epoch 37/50
# 13/13 [==============================] - 133s 10s/step - loss: 0.3518 - val_loss: 0.3535
# Epoch 38/50
# 13/13 [==============================] - 133s 10s/step - loss: 0.3517 - val_loss: 0.3535
# Epoch 39/50
# 13/13 [==============================] - 134s 10s/step - loss: 0.3517 - val_loss: 0.3533
# Epoch 40/50
# 13/13 [==============================] - 133s 10s/step - loss: 0.3516 - val_loss: 0.3533
# Epoch 41/50
# 13/13 [==============================] - 141s 11s/step - loss: 0.3515 - val_loss: 0.3532
# Epoch 42/50
# 13/13 [==============================] - 145s 11s/step - loss: 0.3515 - val_loss: 0.3531
# Epoch 43/50
# 13/13 [==============================] - 133s 10s/step - loss: 0.3514 - val_loss: 0.3532
# Epoch 44/50
# 13/13 [==============================] - 131s 10s/step - loss: 0.3514 - val_loss: 0.3529
# Epoch 45/50
# 13/13 [==============================] - 141s 11s/step - loss: 0.3512 - val_loss: 0.3528
# Epoch 46/50
# 13/13 [==============================] - 141s 11s/step - loss: 0.3512 - val_loss: 0.3528
# Epoch 47/50
# 13/13 [==============================] - 138s 11s/step - loss: 0.3511 - val_loss: 0.3528
# Epoch 48/50
# 13/13 [==============================] - 137s 11s/step - loss: 0.3511 - val_loss: 0.3527
# Epoch 49/50
# 13/13 [==============================] - 135s 10s/step - loss: 0.3510 - val_loss: 0.3526
# Epoch 50/50
# 13/13 [==============================] - 136s 10s/step - loss: 0.3510 - val_loss: 0.3526
# 2/2 [==============================] - 9s 2s/step
